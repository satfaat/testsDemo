# %%
nm_limit_30 = 'Wolfeschlegelsteinhausenberger'
nm_min = "Ian"

nm_773 = "Adolph Blaine Charles David Earl Frederick Gerald Hubert Irvin John Kenneth Lloyd Martin Nero Oliver Paul Quincy Randolph Sherman Thomas Uncas Victor William Xerxes Yancy Zeus ..."
nm_25 = 'happydaysoneveryyerforall'
nm_50 = 'happydaysoneveryyerforallhappydaysoneveryyerforall'
nm_3754 = """
Adolph Blaine Charles David Earl Frederick Gerald Hubert Irvin John Kenneth Lloyd Martin Nero Oliver Paul Quincy Randolph Sherman Thomas Uncas VictorWilliam Xerxes Yancy Zeus ...
"""

print(len(nm_limit))
# Out:
# 30

# %%
# phones
ph_limit_14 = '77777777777777'
print(len(ph_limit))
# Out:
# 14

# %%
# emails
email_3584 = """
...@ligentgeschopfsvonhinzwischensternartigraum.com
"""
email_limit_100 = 'Wolfeschlegelsteinhausenbergerdorffwelchevoralternwarengewissenhaftschaferswessenschafewa@enwohl.com'
print(len(email_limit_100))
# Out:
# 100
